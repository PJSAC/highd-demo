# %%
from pathlib import Path
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Explore HighD Dataset

# %% [markdown]
# ## Load Dataset

# %%
highd_dir = Path('highd')
recordsmeta_file = [record for record in highd_dir.glob('*_recordingMeta.csv')]
tracksmeta_file = [track_meta for track_meta in highd_dir.glob('*_tracksMeta.csv')]
tracks_file = [track for track in highd_dir.glob('*_tracks.csv')]
recordsmeta_file.sort()
tracksmeta_file.sort()
tracks_file.sort()

# %%
pd.read_csv(recordsmeta_file[0]).T
# Out:
#                                      0
# id                                   1
# frameRate                           25
# locationId                           2
# speedLimit                        -1.0
# month                           9.2017
# weekDay                            Tue
# startTime                        08:38
# duration                        901.56
# totalDrivenDistance          418549.19
# totalDrivenTime               13908.12
# numVehicles                       1047
# numCars                            863
# numTrucks                          184
# upperLaneMarkings     8.51;12.59;16.43
# lowerLaneMarkings    21.00;24.96;28.80

# %%
pd.read_csv(tracksmeta_file[0])
# Out:
#         id  width  height  initialFrame  finalFrame  numFrames  class  \
# 0        1   4.85    2.12             1          33         33    Car
# 1        2   4.24    1.92             1         130        130    Car
# 2        3   3.94    1.92             1         157        157    Car
# 3        4   5.05    2.22             1         161        161    Car
# 4        5   4.24    1.82             1         182        182    Car
# ...    ...    ...     ...           ...         ...        ...    ...
# 1042  1043   7.38    2.53         22376       22539        164    Car
# 1043  1044   5.15    2.02         22383       22538        156    Car
# 1044  1045   4.75    2.02         22456       22539         84    Car
# 1045  1046   4.35    2.12         22456       22531         76    Car
# 1046  1047   6.37    3.13         22508       22539         32  Truck
#
#       drivingDirection  traveledDistance  minXVelocity  maxXVelocity  \
# ...

# %%
pd.read_csv(tracks_file[0])
# Out:
#         frame    id       x      y  width  height  xVelocity  yVelocity  \
# 0           1     1  362.26  21.68   4.85    2.12      40.85       0.00
# 1           2     1  363.73  21.68   4.85    2.12      40.87       0.00
# 2           3     1  365.27  21.68   4.85    2.12      40.88       0.00
# 3           4     1  366.83  21.68   4.85    2.12      40.89       0.00
# 4           5     1  368.42  21.68   4.85    2.12      40.90       0.01
# ...       ...   ...     ...    ...    ...     ...        ...        ...
# 348745  22535  1047  366.97  12.54   6.37    3.13     -35.63       0.19
# 348746  22536  1047  365.55  12.55   6.37    3.13     -35.66       0.20
# 348747  22537  1047  364.12  12.56   6.37    3.13     -35.69       0.20
# 348748  22538  1047  362.69  12.57   6.37    3.13     -35.72       0.21
# 348749  22539  1047  361.26  12.58   6.37    3.13     -35.75       0.21
#
#         xAcceleration  yAcceleration  ...  precedingXVelocity  precedingId  \
# ...
